# %%
import zipfile
import os
import urllib.request
import pandas as pd
import csv
import pickle
import numpy as np

# %%
# Global Definitions

# Util Functions
def save_pickle(path, dump):
    with open(path, 'wb') as file:
        pickle.dump(dump, file)

def load_pickle(path):
    with open(path, 'rb') as file:
        return pickle.load(file)

# Embedding Defs
RARE_WORD = 100
STOP_WORD = 1e4
UNKNOWN = 1

# File Names
VOCAB_FILE = "./data/vocab.txt"
STOP_FILE = "./data/stop.txt"
INPUT_FILE = "./data/input.txt"
VOCAB_PKL = "./data/vocab.pkl"
SIM_DATA_URL = "https://journals.plos.org/plosone/article/file?type=supplementary&id=10.1371/journal.pone.0195024.s001"
SIM_DATA_ZIP = "./txtData.zip"
SIM_DATA_FILE = "./data/S1_File.txt"

# %%
def retrieve_data(print_out=False):
    # Retrieve Data If Not In Our Active Directory
    if not os.path.exists(SIM_DATA_ZIP):
        urllib.request.urlretrieve(SIM_DATA_LOC, SIM_DATA_ZIP)

    # Unzip our Data into Usable Form
    if not os.path.exists("./data"):
        with zipfile.ZipFile(SIM_DATA_ZIP, 'r') as zipped_file:
            zipped_file.extractall("./data")


    # Read Our Data into a Pandas Table
    data = pd.read_csv(SIM_DATA_FILE, sep='\t', header=0)

    # Check Our Data
    if print_out:
        print("\n", data.head(), "\n")

print("Retrieving Data...")
retrieve_data(True)
print("Done!")
# Out:
# Retrieving Data...
#
#     PID  DAY_ID                               DX_GROUP_DESCRIPTION  \
# 0    1   73888                                    ANGINA PECTORIS
# 1    1   73888  MONONEURITIS OF UPPER LIMB AND MONONEURITIS MU...
# 2    1   73888  SYMPTOMS INVOLVING RESPIRATORY SYSTEM AND OTHE...
# 3    1   73880                                 ACUTE APPENDICITIS
# 4    1   73880                                  DIABETES MELLITUS
#
#      SERVICE_LOCATION  OP_DATE
# 0      DOCTORS OFFICE    74084
# 1      DOCTORS OFFICE    74084
# 2      DOCTORS OFFICE    74084
# 3  INPATIENT HOSPITAL    74084
# 4  INPATIENT HOSPITAL    74084
#
# Done!

# %%
def data_to_csv():
    # Group Our Data By Description
    desc = data.groupby('DX_GROUP_DESCRIPTION').size().to_frame('SIZE').reset_index()
    rare = desc[desc['SIZE'] > RARE_WORD]
    stop = desc[desc['SIZE'] > STOP_WORD]

    rare = rare.sort_values(by = 'SIZE').reset_index()['DX_GROUP_DESCRIPTION']
    stop = stop.reset_index()['DX_GROUP_DESCRIPTION']
        
    rare.index += 2 # We will follow the studies format of keeping "Unknown" as 1
    
    print("Writing Vocab List to CSV...")
    rare.to_csv(VOCAB_FILE, sep = '\t', header = False, index = True)
    print("Done!")
    
    print("\nWriting Stop Word List to CSV...")
    stop.to_csv(STOP_FILE, sep = '\t', header = False, index = False)
    print("Done!")
    
    print("\nData Successfully Written as {} and {} in CSV Format!".format(VOCAB_FILE, STOP_FILE))
    
data_to_csv()
# Out:
# Writing Vocab List to CSV...
# Done!
#
# Writing Stop Word List to CSV...
# Done!
#
# Data Successfully Written as ./data/vocab.txt and ./data/stop.txt in CSV Format!

# %%
def load_data_from_file():
    word2ind = {}
    
    with open(VOCAB_FILE, 'r') as vocab_file:
        read_in = csv.reader(vocab_file, delimiter='\t')
        word2ind = { entry[1]:int(entry[0]) for entry in read_in }
        
    # Save Ind2Word Vec to Pickled File
    save_pickle(VOCAB_PKL, {val:key for key, val in word2ind.items()})
    
    return word2ind

load_data_from_file()
# load_pickle(VOCAB_PKL)
# Out:
# {'DISEASES OF THE ORAL SOFT TISSUES, EXCLUDING LESIONS SPECIFIC FOR GINGIVA AND TONGUE': 2,
#  'ALCOHOL DEPENDENCE SYNDROME': 3,
#  'FAMILY HISTORY OF MALIGNANT NEOPLASM': 4,
#  'MALIGNANT NEOPLASM OF GALLBLADDER AND EXTRAHEPATIC BILE DUCTS': 5,
#  'OTHER DISORDERS OF PROSTATE': 6,
#  'SPECIFIC NONPSYCHOTIC MENTAL DISORDERS FOLLOWING ORGANIC BRAIN DAMAGE': 7,
#  'ILL-DEFINED INTESTINAL INFECTIONS': 8,
#  'OTHER AND UNSPECIFIED INFECTIOUS AND PARASITIC DISEASES': 9,
#  'DISORDERS OF MENSTRUATION AND OTHER ABNORMAL BLEEDING FROM FEMALE GENITAL TRACT': 10,
#  'TERAZOSIN HYDROCHLORIDE': 11,
#  'OTHER PERSONS SEEKING CONSULTATION WITHOUT COMPLAINT OR SICKNESS': 12,
#  'DISORDERS OF IRIS AND CILIARY BODY': 13,
#  'OTHER DISORDERS OF THYROID': 14,
#  'OPEN WOUND OF TOE(S)': 15,
#  'FALL ON SAME LEVEL FROM SLIPPING, TRIPPING, OR STUMBLING': 16,
#  'TRIAMTERENE': 17,
#  'FRACTURE OF PELVIS': 18,
#  'MALIGNANT NEOPLASM OF LARYNX': 19,
#  'FRACTURE OF TIBIA AND FIBULA': 20,
#  'KETOCONAZOLE': 21,
#  'CINACALCET HYDROCHLORIDE': 22,
#  'ASCORBIC ACID': 23,
#  'CODEINE PHOSPHATE': 24,
#  'OTHER DISORDERS OF PERITONEUM': 25,
#  'FOREIGN BODY IN TRACHEA, BRONCHUS, AND LUNG': 26,
#  'ANKYLOSING SPONDYLITIS AND OTHER INFLAMMATORY SPONDYLOPATHIES': 27,
#  'CHRONIC PHARYNGITIS AND NASOPHARYNGITIS': 28,
#  'SILVER SULFADIAZINE': 29,
#  'LEVOBUNOLOL HYDROCHLORIDE': 30,
#  'LEVALBUTEROL TARTRATE': 31,
#  'OTHER DISORDERS OF MALE GENITAL ORGANS': 32,
#  'ACUTE AND SUBACUTE ENDOCARDITIS': 33,
#  'ATOPIC DERMATITIS AND RELATED CONDITIONS': 34,
#  'COMPLICATIONS AFFECTING SPECIFIED BODY SYSTEMS, NOT ELSEWHERE CLASSIFIED': 35,
#  'POLYARTERITIS NODOSA AND ALLIED CONDITIONS': 36,
#  'FLUCONAZOLE': 37,
#  'PRIMARILY SYSTEMIC AGENTS': 38,
#  'MALIGNANT NEOPLASM OF THYROID GLAND': 39,
#  'FRACTURE OF ONE OR MORE TARSAL AND METATARSAL BONES': 40,
#  'PNEUMOCOCCAL PNEUMONIA [STREPTOCOCCUS PNEUMONIAE PNEUMONIA]': 41,
#  'NIFEDIPINE': 42,
#  'CARISOPRODOL': 43,
#  'OTHER ALVEOLAR AND PARIETOALVEOLAR PNEUMOPATHY': 44,
#  'ACUTE PERICARDITIS': 45,
#  'URETHRAL STRICTURE': 46,
#  'OTHER DERANGEMENT OF JOINT': 47,
#  'RANOLAZINE': 48,
#  'OTHER AND UNSPECIFIED DISORDERS OF METABOLISM': 49,
#  'SPRAINS AND STRAINS OF ANKLE AND FOOT': 50,
#  'SOLIFENACIN SUCCINATE': 51,
#  'MALIGNANT NEOPLASM WITHOUT SPECIFICATION OF SITE': 52,
#  'DUODENAL ULCER': 53,
#  'VASCULAR INSUFFICIENCY OF INTESTINE': 54,
#  'SUPPURATIVE AND UNSPECIFIED OTITIS MEDIA': 55,
#  'DISEASES OF HAIR AND HAIR FOLLICLES': 56,
#  'TRANSIENT ORGANIC PSYCHOTIC CONDITIONS': 57,
#  'SEVELAMER HYDROCHLORIDE': 58,
#  'REGIONAL ENTERITIS': 59,
#  'COLCHICINE': 60,
#  'NEOPLASM OF UNCERTAIN BEHAVIOR OF ENDOCRINE GLANDS AND NERVOUS SYSTEM': 61,
#  'CONGENITAL ANOMALIES OF URINARY SYSTEM': 62,
#  'DISORDERS OF THE PITUITARY GLAND AND ITS HYPOTHALAMIC CONTROL': 63,
#  'CORNEAL OPACITY AND OTHER DISORDERS OF CORNEA': 64,
#  'INFLUENZA': 65,
#  'CALCIUM': 66,
#  'PLACE OF OCCURRENCE': 67,
#  'CARBAMAZEPINE': 68,
#  'OTHER CONGENITAL MUSCULOSKELETAL ANOMALIES': 69,
#  'DISORDERS OF ADRENAL GLANDS': 70,
#  'OTHER ACQUIRED DEFORMITIES OF LIMBS': 71,
#  'INTRACRANIAL INJURY OF OTHER AND UNSPECIFIED NATURE': 72,
#  'DISORDERS OF PLASMA PROTEIN METABOLISM': 73,
#  'MULTIPLE SCLEROSIS': 74,
#  'FRACTURE OF RIB(S), STERNUM, LARYNX, AND TRACHEA': 75,
#  'MORPHINE SULFATE': 76,
#  'DISLOCATION OF KNEE': 77,
#  'PHENYTOIN SODIUM': 78,
#  'OTHER ANEURYSM': 79,
#  'ERYTHEMATOUS CONDITIONS': 80,
#  'MALIGNANT NEOPLASM OF BRAIN': 81,
#  'ERYTHEMATOSQUAMOUS DERMATOSIS': 82,
#  'PEPTIC ULCER, SITE UNSPECIFIED': 83,
#  'LANSOPRAZOLE': 84,
#  'LACTULOSE': 85,
#  'MALIGNANT NEOPLASM OF LIVER AND INTRAHEPATIC BILE DUCTS': 86,
#  'SODIUM BICARBONATE': 87,
#  'PANTOPRAZOLE SODIUM': 88,
#  'DISEASES OF AORTIC VALVE': 89,
#  'FLUTICASONE PROPIONATE': 90,
#  'PREDNISOLONE ACETATE': 91,
#  'MALIGNANT NEOPLASM OF STOMACH': 92,
#  'CARCINOMA IN SITU OF SKIN': 93,
#  'CLOTRIMAZOLE': 94,
#  'BULBUS CORDIS ANOMALIES AND ANOMALIES OF CARDIAC SEPTAL CLOSURE': 95,
#  'MIGRAINE': 96,
#  'INFLAMMATORY DISEASE OF CERVIX, VAGINA, AND VULVA': 97,
#  'BETAMETHASONE DIPROPIONATE': 98,
#  'OTHER OPEN WOUND OF HEAD': 99,
#  'SUBARACHNOID, SUBDURAL, AND EXTRADURAL HEMORRHAGE, FOLLOWING INJURY': 100,
#  'NONSPECIFIC ABNORMAL HISTOLOGICAL AND IMMUNOLOGICAL FINDINGS': 101,
#  'HYDRONEPHROSIS': 102,
#  'PROMETHAZINE HYDROCHLORIDE': 103,
#  'INTRACEREBRAL HEMORRHAGE': 104,
#  'NONSUPPURATIVE OTITIS MEDIA AND EUSTACHIAN TUBE DISORDERS': 105,
#  'MECLIZINE HYDROCHLORIDE': 106,
#  'FAMOTIDINE': 107,
#  'CORNS AND CALLOSITIES': 108,
#  'PAROXETINE HYDROCHLORIDE HEMIHYDRATE': 109,
#  'BRONCHIECTASIS': 110,
#  'METRONIDAZOLE': 111,
#  'NEPHROTIC SYNDROME': 112,
#  'MALIGNANT NEOPLASM OF TONGUE': 113,
#  'SPECIAL SCREENING FOR OTHER CONDITIONS': 114,
#  'MUSCULAR DYSTROPHIES AND OTHER MYOPATHIES': 115,
#  'TIMOLOL MALEATE': 116,
#  'DISORDERS OF PARATHYROID GLAND': 117,
#  'PNEUMOTHORAX': 118,
#  'ACQUIRED DEFORMITIES OF TOE': 119,
#  'ACUTE PHARYNGITIS': 120,
#  'OTHER DISORDERS OF BILIARY TRACT': 121,
#  'ULCERATIVE COLITIS': 122,
#  'INTERNAL DERANGEMENT OF KNEE': 123,
#  'NEOMYCIN SULFATE': 124,
#  'INFECTION WITH DRUG-RESISTANT MICROORGANISMS': 125,
#  'FEXOFENADINE HYDROCHLORIDE': 126,
#  'CLINDAMYCIN HYDROCHLORIDE': 127,
#  'LEVETIRACETAM': 128,
#  'PNEUMONIA DUE TO OTHER SPECIFIED ORGANISM': 129,
#  'NONINFECTIVE DISORDERS OF LYMPHATIC CHANNELS': 130,
#  'CLOBETASOL PROPIONATE': 131,
#  'LIVER ABSCESS AND SEQUELAE OF CHRONIC LIVER DISEASE': 132,
#  'HYDROCORTISONE': 133,
#  'AMIODARONE HYDROCHLORIDE': 134,
#  'NONTOXIC NODULAR GOITER': 135,
#  'VERTIGINOUS SYNDROMES AND OTHER DISORDERS OF VESTIBULAR SYSTEM': 136,
#  'INFLAMMATION OF EYELIDS': 137,
#  'NONSPECIFIC ABNORMAL FINDINGS IN OTHER BODY SUBSTANCES': 138,
#  'OTHER NONORGANIC PSYCHOSES': 139,
#  'LIDOCAINE': 140,
#  'DISORDERS OF THE AUTONOMIC NERVOUS SYSTEM': 141,
#  'NEED FOR PROPHYLACTIC VACCINATION AND INOCULATION AGAINST COMBINATIONS OF DISEASES': 142,
#  'LYMPHOSARCOMA AND RETICULOSARCOMA': 143,
#  'DISORDERS OF PENIS': 144,
#  'DISEASES OF OTHER ENDOCARDIAL STRUCTURES': 145,
#  'ESZOPICLONE': 146,
#  'MALIGNANT MELANOMA OF SKIN': 147,
#  'OTHER ACQUIRED DEFORMITY': 148,
#  'BECLOMETHASONE DIPROPIONATE': 149,
#  'DISORDERS OF LACRIMAL SYSTEM': 150,
#  'CARCINOMA IN SITU OF BREAST AND GENITOURINARY SYSTEM': 151,
#  'ACQUIRED HEMOLYTIC ANEMIAS': 152,
#  'PAIN AND OTHER SYMPTOMS ASSOCIATED WITH FEMALE GENITAL ORGANS': 153,
#  'SPRAINS AND STRAINS OF OTHER AND UNSPECIFIED PARTS OF BACK': 154,
#  'PRURITUS AND RELATED CONDITIONS': 155,
#  'FRACTURE OF OTHER AND UNSPECIFIED PARTS OF FEMUR': 156,
#  'HEMIPLEGIA AND HEMIPARESIS': 157,
#  'MEGESTROL ACETATE': 158,
#  'ALLOPURINOL': 159,
#  'MYELOID LEUKEMIA': 160,
#  'GENITAL PROLAPSE': 161,
#  'CEPHALEXIN': 162,
#  'PAIN, NOT ELSEWHERE CLASSIFIED': 163,
#  'CANDIDIASIS': 164,
#  'OPEN WOUND OF FOOT EXCEPT TOE(S) ALONE': 165,
#  'MALIGNANT NEOPLASM OF PANCREAS': 166,
#  'SODIUM CHLORIDE': 167,
#  'FRACTURE OF RADIUS AND ULNA': 168,
#  'EPOETIN ALFA': 169,
#  'OTHER DISEASES OF BLOOD AND BLOOD-FORMING ORGANS': 170,
#  'OTHER DISORDERS OF EYELIDS': 171,
#  'HYDROXYZINE HYDROCHLORIDE': 172,
#  'CYCLOBENZAPRINE HYDROCHLORIDE': 173,
#  'FRACTURE OF ANKLE': 174,
#  'MONONEURITIS OF LOWER LIMB': 175,
#  'SECONDARY MALIGNANT NEOPLASM OF RESPIRATORY AND DIGESTIVE SYSTEMS': 176,
#  'POLYMYALGIA RHEUMATICA': 177,
#  'OTHER DISORDERS OF PANCREATIC INTERNAL SECRETION': 178,
#  'DISEASES OF MITRAL VALVE': 179,
#  'OTHER AND UNSPECIFIED FALL': 180,
#  'NAPROXEN': 181,
#  'PNEUMONITIS DUE TO SOLIDS AND LIQUIDS': 182,
#  'POLYMYXIN B SULFATE': 183,
#  'MALIGNANT NEOPLASM OF KIDNEY AND OTHER AND UNSPECIFIED URINARY ORGANS': 184,
#  'DISEASES OF MITRAL AND AORTIC VALVES': 185,
#  'TESTICULAR DYSFUNCTION': 186,
#  'INGUINAL HERNIA': 187,
#  'OTHER DISORDERS OF EAR': 188,
#  'OTHER DISEASES DUE TO VIRUSES AND CHLAMYDIAE': 189,
#  "HODGKIN'S DISEASE": 190,
#  'GLIMEPIRIDE': 191,
#  'RISPERIDONE': 192,
#  'HYDROCODONE BITARTRATE': 193,
#  'OTHER AND UNSPECIFIED INTRACRANIAL HEMORRHAGE': 194,
#  'OTHER DISEASES OF UPPER RESPIRATORY TRACT': 195,
#  'OXYCODONE HYDROCHLORIDE': 196,
#  'PROBLEMS WITH LIMBS AND OTHER PROBLEMS': 197,
#  'OTHER CONGENITAL ANOMALIES OF HEART': 198,
#  'METOCLOPRAMIDE HYDROCHLORIDE': 199,
#  'CHRONIC SINUSITIS': 200,
#  'CURVATURE OF SPINE': 201,
#  'OTHER PARALYTIC SYNDROMES': 202,
#  'VISUAL DISTURBANCES': 203,
#  'INFLAMMATORY DISEASES OF PROSTATE': 204,
#  'ALENDRONATE SODIUM': 205,
#  'BENIGN NEOPLASM OF SKIN': 206,
#  'MALIGNANT NEOPLASM OF ESOPHAGUS': 207,
#  'OTHER DISEASES OF PERICARDIUM': 208,
#  'INFECTIONS OF KIDNEY': 209,
#  'PROPRANOLOL HYDROCHLORIDE': 210,
#  'OTHER LOCAL INFECTIONS OF SKIN AND SUBCUTANEOUS TISSUE': 211,
#  'NYSTATIN': 212,
#  'CONTUSION OF LOWER LIMB AND OF OTHER AND UNSPECIFIED SITES': 213,
#  'OTHER EXTRAPYRAMIDAL DISEASE AND ABNORMAL MOVEMENT DISORDERS': 214,
#  'ORGANIC SLEEP DISORDERS': 215,
#  'OBSERVATION AND EVALUATION FOR SUSPECTED CONDITIONS': 216,
#  'ESOXYBUTYNIN CHLORIDE': 217,
#  'HERPES ZOSTER': 218,
#  'DISORDERS OF FUNCTION OF STOMACH': 219,
#  'OTHER DEPENDENCE ON MACHINES': 220,
#  'BENAZEPRIL HYDROCHLORIDE': 221,
#  'SPRAINS AND STRAINS OF SHOULDER AND UPPER ARM': 222,
#  'OTHER DISEASES OF RESPIRATORY SYSTEM': 223,
#  'TIMOLOL': 224,
#  'OTHER CONGENITAL ANOMALIES OF CIRCULATORY SYSTEM': 225,
#  'LORAZEPAM': 226,
#  'ATTENTION TO ARTIFICIAL OPENINGS': 227,
#  'OPEN WOUND OF OTHER AND UNSPECIFIED SITES, EXCEPT LIMBS': 228,
#  'CELLULITIS AND ABSCESS OF FINGER AND TOE': 229,
#  'THEOPHYLLINE ANHYDROUS': 230,
#  'FLUOXETINE HYDROCHLORIDE': 231,
#  'MALIGNANT NEOPLASM OF RECTUM, RECTOSIGMOID JUNCTION, AND ANUS': 232,
#  'OTHER DISORDERS OF BREAST': 233,
#  'CALCULUS OF KIDNEY AND URETER': 234,
#  'MENOPAUSAL AND POSTMENOPAUSAL DISORDERS': 235,
#  'CLONIDINE HYDROCHLORIDE': 236,
#  'POLYETHYLENE GLYCOL 3350': 237,
#  'TRIAMCINOLONE ACETONIDE': 238,
#  'ACUTE SINUSITIS': 239,
#  'OTHER HYPERTROPHIC AND ATROPHIC CONDITIONS OF SKIN': 240,
#  'DISEASES OF SEBACEOUS GLANDS': 241,
#  'MULTIPLE MYELOMA AND IMMUNOPROLIFERATIVE NEOPLASMS': 242,
#  'OTHER DISORDERS OF LIVER': 243,
#  'CIPROFLOXACIN HYDROCHLORIDE': 244,
#  'DIFFUSE DISEASES OF CONNECTIVE TISSUE': 245,
#  'MALIGNANT NEOPLASM OF OVARY AND OTHER UTERINE ADNEXA': 246,
#  'FRACTURE OF HUMERUS': 247,
#  'ALPRAZOLAM': 248,
#  'BRONCHITIS, NOT SPECIFIED AS ACUTE OR CHRONIC': 249,
#  'DISORDERS OF CONJUNCTIVA': 250,
#  'LYMPHOID LEUKEMIA': 251,
#  'CYSTITIS': 252,
#  'GEMFIBROZIL': 253,
#  'ACETAMINOPHEN': 254,
#  'HEMORRHOIDS': 255,
#  'BACTERIAL INFECTION IN CONDITIONS CLASSIFIED ELSEWHERE AND OF UNSPECIFIED SITE': 256,
#  'EPILEPSY': 257,
#  'CIMETIDINE': 258,
#  'NEED FOR PROPHYLACTIC VACCINATION AND INOCULATION AGAINST BACTERIAL DISEASES': 259,
#  'PIOGLITAZONE': 260,
#  'VIRAL HEPATITIS': 261,
#  'DOXAZOSIN MESYLATE': 262,
#  'OTHER DISORDERS OF GALLBLADDER': 263,
#  'ARTIFICIAL OPENING STATUS': 264,
#  'OTHER DISORDERS OF EYE': 265,
#  'OTHER DISORDERS OF ARTERIES AND ARTERIOLES': 266,
#  'AMOXICILLIN': 267,
#  'RAMIPRIL': 268,
#  'PRAVASTATIN SODIUM': 269,
#  'PSORIASIS AND SIMILAR DISORDERS': 270,
#  'FRACTURE OF VERTEBRAL COLUMN WITHOUT MENTION OF SPINAL CORD LESION': 271,
#  'SECONDARY MALIGNANT NEOPLASM OF OTHER SPECIFIED SITES': 272,
#  'MONONEURITIS OF UPPER LIMB AND MONONEURITIS MULTIPLEX': 273,
#  'NONDEPENDENT ABUSE OF DRUGS': 274,
#  'NITROGLYCERIN': 275,
#  'VARICOSE VEINS OF LOWER EXTREMITIES': 276,
#  'INTESTINAL INFECTIONS DUE TO OTHER ORGANISMS': 277,
#  'IPRATROPIUM BROMIDE': 278,
#  'DISORDERS OF MINERAL METABOLISM': 279,
#  'OPEN WOUND OF KNEE, LEG [EXCEPT THIGH], AND ANKLE': 280,
#  'PERITONITIS': 281,
#  'RABEPRAZOLE SODIUM': 282,
#  'HEARING LOSS': 283,
#  'OTHER AND UNSPECIFIED PROTEIN-CALORIE MALNUTRITION': 284,
#  'DIGOXIN': 285,
#  'FINASTERIDE': 286,
#  'ENALAPRIL MALEATE': 287,
#  'OTHER DISORDERS OF BLADDER': 288,
#  'EMPHYSEMA': 289,
#  'ARTERIAL EMBOLISM AND THROMBOSIS': 290,
#  'DISEASES OF PANCREAS': 291,
#  'OTHER BACTERIAL PNEUMONIA': 292,
#  'FITTING AND ADJUSTMENT OF OTHER DEVICE': 293,
#  'HYDROCHLOROTHIAZIDE': 294,
#  'FELODIPINE': 295,
#  'FUROSEMIDE': 296,
#  'NEPHRITIS AND NEPHROPATHY, NOT SPECIFIED AS ACUTE OR CHRONIC': 297,
#  'ACUTE UPPER RESPIRATORY INFECTIONS OF MULTIPLE OR UNSPECIFIED SITES': 298,
#  'MIRTAZAPINE': 299,
#  'DISEASES OF NAIL': 300,
#  'ZOLPIDEM TARTRATE': 301,
#  'TRIMETHOPRIM': 302,
#  'SULFAMETHOXAZOLE': 303,
#  'OTHER CONDITIONS OF BRAIN': 304,
#  'OTHER DISORDERS OF SYNOVIUM, TENDON, AND BURSA': 305,
#  'INJURY, OTHER AND UNSPECIFIED': 306,
#  'OTHER AND ILL-DEFINED CEREBROVASCULAR DISEASE': 307,
#  'OTHER DISORDERS OF SKIN AND SUBCUTANEOUS TISSUE': 308,
#  'CHOLELITHIASIS': 309,
#  'APLASTIC ANEMIA': 310,
#  'THYROTOXICOSIS WITH OR WITHOUT GOITER': 311,
#  'OTHER NONSPECIFIC ABNORMAL FINDINGS': 312,
#  'AZITHROMYCIN': 313,
#  'PIOGLITAZONE HYDROCHLORIDE': 314,
#  'OTHER HERNIA OF ABDOMINAL CAVITY WITHOUT MENTION OF OBSTRUCTION OR GANGRENE': 315,
#  'SPIRONOLACTONE': 316,
#  'SERTRALINE HYDROCHLORIDE': 317,
#  'OTHER PERSONAL HISTORY PRESENTING HAZARDS TO HEALTH': 318,
#  'MALIGNANT NEOPLASM OF BLADDER': 319,
#  'PULMONARY CONGESTION AND HYPOSTASIS': 320,
#  'NONSPECIFIC FINDINGS ON EXAMINATION OF URINE': 321,
#  'OTHER ORTHOPEDIC AFTERCARE': 322,
#  'RANITIDINE HYDROCHLORIDE': 323,
#  'IBUPROFEN': 324,
#  'POSTINFLAMMATORY PULMONARY FIBROSIS': 325,
#  'OSTEOMYELITIS, PERIOSTITIS, AND OTHER INFECTIONS INVOLVING BONE': 326,
#  'SENILE AND PRESENILE ORGANIC PSYCHOTIC CONDITIONS': 327,
#  'INFLAMMATORY AND TOXIC NEUROPATHY': 328,
#  'TRAMADOL HYDROCHLORIDE': 329,
#  'NEOPLASM OF UNSPECIFIED NATURE': 330,
#  'OTHER AND UNSPECIFIED ARTHROPATHIES': 331,
#  'DISORDERS RESULTING FROM IMPAIRED RENAL FUNCTION': 332,
#  'DEFICIENCY OF B-COMPLEX COMPONENTS': 333,
#  'PURPURA AND OTHER HEMORRHAGIC CONDITIONS': 334,
#  'GLIPIZIDE': 335,
#  'TRAZODONE HYDROCHLORIDE': 336,
#  'OTHER NONINFECTIVE GASTROENTERITIS AND COLITIS': 337,
#  'OTHER DISORDERS OF CIRCULATORY SYSTEM': 338,
#  'GASTRITIS AND DUODENITIS': 339,
#  'OTHER COMPLICATIONS OF PROCEDURES, NOT ELSEWHERE CLASSIFIED': 340,
#  'CHRONIC LIVER DISEASE AND CIRRHOSIS': 341,
#  'ALLERGIC RHINITIS': 342,
#  'HEREDITARY AND IDIOPATHIC PERIPHERAL NEUROPATHY': 343,
#  'BENIGN NEOPLASM OF OTHER PARTS OF DIGESTIVE SYSTEM': 344,
#  'HYDRALAZINE HYDROCHLORIDE': 345,
#  'INTESTINAL OBSTRUCTION WITHOUT MENTION OF HERNIA': 346,
#  'DISORDERS OF REFRACTION AND ACCOMMODATION': 347,
#  'OTHER DEFICIENCY ANEMIAS': 348,
#  'DISORDERS OF EXTERNAL EAR': 349,
#  'CIPROFLOXACIN': 350,
#  'HYPERTENSIVE HEART AND RENAL DISEASE': 351,
#  'OTHER ACUTE AND SUBACUTE FORM OF ISCHEMIC HEART DISEASE': 352,
#  "PARKINSON'S DISEASE": 353,
#  'PAROXETINE HYDROCHLORIDE': 354,
#  'FOLLOW-UP EXAMINATION': 355,
#  'GABAPENTIN': 356,
#  'CITALOPRAM HYDROBROMIDE': 357,
#  'AORTIC ANEURYSM AND DISSECTION': 358,
#  'CONTACT DERMATITIS AND OTHER ECZEMA': 359,
#  'CONDUCTION DISORDERS': 360,
#  'MALIGNANT NEOPLASM OF COLON': 361,
#  'FRACTURE OF NECK OF FEMUR': 362,
#  'DEPRESSIVE DISORDER, NOT ELSEWHERE CLASSIFIED': 363,
#  'PERSONAL HISTORY OF MALIGNANT NEOPLASM': 364,
#  'TRANSCIENT CEREBRAL ISCHEMIA': 365,
#  'OTHER MALIGNANT NEOPLASM OF LYMPHOID AND HISTIOCYTIC TISSUE': 366,
#  'NEUROTIC DISORDERS': 367,
#  'FUNCTIONAL DIGESTIVE DISORDERS, NOT ELSEWHERE CLASSIFIED': 368,
#  'SPONDYLOSIS AND ALLIED DISORDERS': 369,
#  'OTHER DISORDERS OF INTESTINE': 370,
#  'OLMESARTAN MEDOXOMIL': 371,
#  'PHLEBITIS AND THROMBOPHLEBITIS': 372,
#  'SYMPTOMS CONCERNING NUTRITION, METABOLISM, AND DEVELOPMENT': 373,
#  'ACUTE PULMONARY HEART DISEASE': 374,
#  'DONEPEZIL HYDROCHLORIDE': 375,
#  'CERTAIN ADVERSE EFFECTS, NOT ELSEWHERE CLASSIFIED': 376,
#  'OTHER CEREBRAL DEGENERATIONS': 377,
#  'AFFECTIVE PSYCHOSES': 378,
#  'GOUT': 379,
#  'DISORDERS OF MUSCLE, LIGAMENT, AND FASCIA': 380,
#  'COMPLICATIONS PECULIAR TO CERTAIN SPECIFIED PROCEDURES': 381,
#  'DIVERTICULA OF INTESTINE': 382,
#  'PERIPHERAL ENTHESOPATHIES AND ALLIED SYNDROMES': 383,
#  'PERSONAL HISTORY OF CERTAIN OTHER DISEASES': 384,
#  'ATENOLOL': 385,
#  'OTHER ORGANIC PSYCHOTIC CONDITIONS (CHRONIC)': 386,
#  'CHRONIC PULMONARY HEART DISEASE': 387,
#  'LATE EFFECTS OF CEREBROVASCULAR DISEASE': 388,
#  'OLD MYOCARDIAL INFARCTION': 389,
#  'OTHER DISORDERS OF CERVICAL REGION': 390,
#  'OCCLUSION AND STENOSIS OF PRECEREBRAL ARTERIES': 391,
#  'METOPROLOL SUCCINATE': 392,
#  'DISEASES OF WHITE BLOOD CELLS': 393,
#  'SYMPTOMS INVOLVING HEAD AND NECK': 394,
#  'ACUTE BRONCHITIS AND BRONCHIOLITIS': 395,
#  'OTHER VENOUS EMBOLISM AND THROMBOSIS': 396,
#  'DERMATOPHYTOSIS': 397,
#  'MALIGNANT NEOPLASM OF TRACHEA, BRONCHUS, AND LUNG': 398,
#  'COAGULATION DEFECTS': 399,
#  'OTHER RETINAL DISORDERS': 400,
#  'ISOSORBIDE MONONITRATE': 401,
#  'OCCLUSION OF CEREBRAL ARTERIES': 402,
#  'SEPTICEMIA': 403,
#  'DILTIAZEM HYDROCHLORIDE': 404,
#  'LOVASTATIN': 405,
#  'ANGINA PECTORIS': 406,
#  'RENAL FAILURE, UNSPECIFIED': 407,
#  'OBESITY AND OTHER HYPERALIMENTATION': 408,
#  'ORGAN OR TISSUE REPLACED BY TRANSPLANT': 409,
#  'RHEUMATOID ARTHRITIS AND OTHER INFLAMMATORY POLYARTHROPATHIES': 410,
#  'POTASSIUM CHLORIDE': 411,
#  'HYPOTENSION': 412,
#  'CHRONIC BRONCHITIS': 413,
#  'OMEPRAZOLE': 414,
#  'SYMPTOMS INVOLVING NERVOUS AND MUSCULOSKELETAL SYSTEMS': 415,
#  'ALBUTEROL SULFATE': 416,
#  'GLAUCOMA': 417,
#  'ASTHMA': 418,
#  'MALIGNANT NEOPLASM OF PROSTATE': 419,
#  'GASTROINTESTINAL HEMORRHAGE': 420,
#  'MALIGNANT NEOPLASM OF FEMALE BREAST': 421,
#  'NONSPECIFIC ABNORMAL FINDINGS ON RADIOLOGICAL AND OTHER EXAMINATION OF BODY STRUCTURE': 422,
#  'GENERAL MEDICAL EXAMINATION': 423,
#  'METFORMIN HYDROCHLORIDE': 424,
#  'HYPERTENSIVE RENAL DISEASE': 425,
#  'EZETIMIBE': 426,
#  'AMLODIPINE BESYLATE': 427,
#  'NEOPLASM OF UNCERTAIN BEHAVIOR OF OTHER AND UNSPECIFIED SITES AND TISSUES': 428,
#  'PLEURISY': 429,
#  'SYMPTOMS INVOLVING URINARY SYSTEM': 430,
#  'HYPERPLASIA OF PROSTATE': 431,
#  'OTHER MALIGNANT NEOPLASM OF SKIN': 432,
#  'ACUTE BUT ILL-DEFINED CEREBROVASCULAR DISEASE': 433,
#  'INTERVERTEBRAL DISC DISORDERS': 434,
#  'ATHEROSCLEROSIS': 435,
#  'LEVOTHYROXINE SODIUM': 436,
#  'OTHER DISORDERS OF KIDNEY AND URETER': 437,
#  'OTHER ILL-DEFINED AND UNKNOWN CAUSES OF MORBIDITY AND MORTALITY': 438,
#  'METOPROLOL TARTRATE': 439,
#  'NONSPECIFIC ABNORMAL RESULTS OF FUNCTION STUDIES': 440,
#  'OTHER PERIPHERAL VASCULAR DISEASE': 441,
#  'CATARACT': 442,
#  'CARVEDILOL': 443,
#  'OTHER DERMATOSES': 444,
#  'CARE INVOLVING USE OF REHABILITATION PROCEDURES': 445,
#  'NEED FOR PROPHYLACTIC VACCINATION AND INOCULATION AGAINST CERTAIN VIRAL DISEASES': 446,
#  'OTHER CELLULITIS AND ABSCESS': 447,
#  'CHRONIC ULCER OF SKIN': 448,
#  'ACUTE RENAL FAILURE': 449,
#  'DISEASES OF ESOPHAGUS': 450,
#  'ACUTE MYOCARDIAL INFARCTION': 451,
#  'SPECIAL SCREENING FOR MALIGNANT NEOPLASMS': 452,
#  'OTHER DISORDERS OF BONE AND CARTILAGE': 453,
#  'ILL-DEFINED DESCRIPTIONS AND COMPLICATIONS OF HEART DISEASE': 454,
#  'ORGAN OR TISSUE REPLACED BY OTHER MEANS': 455,
#  'IRON DEFICIENCY ANEMIAS': 456,
#  'WARFARIN SODIUM': 457,
#  'CLOPIDOGREL BISULFATE': 458,
#  'OTHER SYMPTOMS INVOLVING ABDOMEN AND PELVIS': 459,
#  'SYMPTOMS INVOLVING CARDIOVASCULAR SYSTEM': 460,
#  'NONSPECIFIC FINDINGS ON EXAMINATION OF BLOOD': 461,
#  'SYMPTOMS INVOLVING DIGESTIVE SYSTEM': 462,
#  'OTHER DISORDERS OF SOFT TISSUES': 463,
#  'PNEUMONIA, ORGANISM UNSPECIFIED': 464,
#  'LISINOPRIL': 465,
#  'CARDIOMYOPATHY': 466,
#  'SYMPTOMS INVOLVING SKIN AND OTHER INTEGUMENTARY TISSUE': 467,
#  'SPECIAL INVESTIGATIONS AND EXAMINATIONS': 468,
#  'DISORDERS OF FLUID, ELECTROLYTE, AND ACID-BASE BALANCE': 469,
#  'OTHER DISEASES OF ENDOCARDIUM': 470,
#  'SIMVASTATIN': 471,
#  'OTHER AND UNSPECIFIED DISORDERS OF BACK': 472,
#  'OTHER AND UNSPECIFIED DISORDER OF JOINT': 473,
#  'OSTEOARTHROSIS AND ALLIED DISORDERS': 474,
#  'HYPERTENSIVE HEART DISEASE': 475,
#  'ACQUIRED HYPOTHYROIDISM': 476,
#  'OTHER DISEASES OF LUNG': 477,
#  'OTHER DISORDERS OF URETHRA AND URINARY TRACT': 478,
#  'OTHER POSTSURGICAL STATES': 479,
#  'CHRONIC RENAL FAILURE': 480,
#  'GENERAL SYMPTOMS': 481,
#  'CHRONIC AIRWAYS OBSTRUCTION, NOT ELSEWHERE CLASSIFIED': 482,
#  'OTHER AND UNSPECIFIED ANEMIAS': 483,
#  'OTHER AND UNSPECIFIED AFTERCARE': 484,
#  'SYMPTOMS INVOLVING RESPIRATORY SYSTEM AND OTHER CHEST SYMPTOMS': 485,
#  'OTHER FORMS OF CHRONIC ISCHEMIC HEART DISEASE': 486,
#  'DISORDERS OF LIPOID METABOLISM': 487,
#  'DIABETES MELLITUS': 488,
#  'HEART FAILURE': 489,
#  'ESSENTIAL HYPERTENSION': 490,
#  'CARDIAC DYSRHYTHMIAS': 491}

# %%
def fix_format(word2ind, events):
    with open(INPUT_FILE, 'r') as input_file:
        file_header = input_file.readline().strip().split('\t')
        pos = { entry : i for i, entry in enumerate(file_header) }
        
        docs, doc, sent, labels, label = ([], ) * 5
        read_in = csv.reader(input_file, delimiter='\t')
